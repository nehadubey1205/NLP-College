# %% [markdown]
# <a href="https://colab.research.google.com/github/nehadubey1205/NLP-college/blob/main/ResearchPaper_SentEmo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Assignment-1

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt

# %%
drive.mount("/content/drive/", force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
data= pd.read_csv(r'/content/drive/MyDrive/Bully_Sent_Emo_IEEEIC_6084.csv')
data.head(10)
# Out:
#                                               Tweets  \
# 0      Teri maa ki chut me Shivsena ka lund gaya kya
# 1  Han muje pata hai teri maa ka ke gufa me jati thi
# 2  Tum kaha se aa gye bhai tumlog toh saree pehen...
# 3  Koi moti🙊kisi ki besti😁 baisn ka or channey ki...
# 4     Rahul kanwal aaj nanga hoke road per nachega 😂
# 5  @riteshrajwada Good morning Raj bhaiya apka di...
# 6  Tera baap bi paltu kutta Hoga Teri maa ka agar...
# 7       Kya be tihari fan \nHar baar gandu ki har...
# 8  @apeidiotstuff Hi deer\n\nYara tum ko shaadi p...
# 9  @iffii_khan1 @HoorainPervaiz @RehamKhan1 Randi...
#
#                                     Processed_Tweets  Bully_Label  \
# 0      Teri maa ki chut me Shivsena ka lund gaya kya            1
# 1  Han muje pata hai teri maa ka ke gufa me jati thi            1
# 2  Tum kaha se aa gye bhai tumlog toh saree pehen...            0
# 3  Koi motikisi ki besti baisn ka or channey ki d...            1
# ...

# %%
data['Sentiment_label'].value_counts()
# Out:
# Negative    3227
# Positive    1530
# Neutral     1327
# Name: Sentiment_label, dtype: int64

# %%
data['Bully_Label'].value_counts()# positive and neutral =0 , negative =1
# Out:
# 1    3050
# 0    3034
# Name: Bully_Label, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6084 entries, 0 to 6083
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Tweets            6084 non-null   object
#  1   Processed_Tweets  6084 non-null   object
#  2   Bully_Label       6084 non-null   int64
#  3   Sentiment_label   6084 non-null   object
#  4   Emotion_label     6084 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 237.8+ KB

# %%
data.isnull().sum()
# Out:
# Tweets              0
# Processed_Tweets    0
# Bully_Label         0
# Sentiment_label     0
# Emotion_label       0
# dtype: int64

# %% [markdown]
# Question-2

# %%
data.shape
# Out:
# (6084, 5)

# %%
#data = data(np.random.rand(10, 4), columns=['Bully_Label',	'Sentiment_label','Emotion_label'])
df = pd.DataFrame(data, columns=['Bully_Label',	'Sentiment_label','Emotion_label'])
#df.plot(x="Emotion_label", y=['Bully_Label'], kind="bar", figsize=(9, 8))
#[1261]: df2.plot(kind='bar');


df['Sentiment_label'].value_counts().plot(kind='bar')

# %%
df['Emotion_label'].value_counts().plot(kind='bar')

# %%
df['Bully_Label'].value_counts().plot(kind='bar')

# %%
df['Emotion_label'].value_counts().head(10).plot.pie()

# Unsquish the pie.
import matplotlib.pyplot as plt
plt.gca().set_aspect('equal')

# %%
df['Sentiment_label'].value_counts().head(10).plot.pie()

plt.gca().set_aspect('equal')

# %%
from collections import Counter

# %% [markdown]
# Q-3, word count

# %%
data['Emotion_label'].value_counts()
# Out:
# Others       1735
# Disgust      1678
# Happiness    1367
# Anger         900
# Sadness       254
# Surprise      114
# Fear           36
# Name: Emotion_label, dtype: int64

# %% [markdown]
# Question-4
# ''Preprocessing: Create a new column ‘preprocessed_text’ ''

# %%
from google.colab import files

# %%
import io

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
data_path = io.StringIO(uploaded['fra.txt'].decode('utf-8'))
with open(data_path, 'rb') as f:
    lines = f.read().split('\n')

# %%
with open("/content/stopWord.txt",'r') as file:
    text = file.read().rstrip()
   # print(type(text))
    print(text)
# Out:
# a
# aadi
# aaj
# aap
# aapne
# aata
# aati
# aaya
# aaye
# ab
# abbe
# abbey
# abe
# abhi
# able
# about
# above
# accha
# according
# accordingly
# acha
# achcha
# across
# actually
# after
# afterwards
# again
# against
# agar
# ain
# aint
# ain't
# aisa
# aise
# aisi
# alag
# all
# allow
# allows
# almost
# alone
# along
# already
# also
# although
# always
# am
# among
# amongst
# an
# and
# andar
# another
# any
# anybody
# anyhow
# anyone
# anything
# anyway
# anyways
# anywhere
# ap
# apan
# apart
# apna
# apnaa
# apne
# apni
# appear
# are
# aren
# arent
# aren't
# around
# arre
# as
# aside
# ask
# asking
# at
# aur
# avum
# aya
# aye
# baad
# baar
# bad
# bahut
# bana
# banae
# banai
# banao
# banaya
# banaye
# banayi
# banda
# bande
# bandi
# bane
# bani
# bas
# bata
# batao
# bc
# be
# became
# because
# become
# becomes
# becoming
# been
# before
# beforehand
# behind
# being
# below
# beside
# besides
# best
# better
# between
# beyond
# bhai
# bheetar
# bhi
# bhitar
# ...

# %%
my_list = text.split()

# %%
#my_list = [line.split(' ') for line in open("stopWord.txt")]

# %%
pat = '|'.join(my_list)
data['Processed_Tweets_1'] = data.Processed_Tweets.str.lower().replace(pat,'', regex=True)

# %%
data.head(5)
# Out:
#                                               Tweets  \
# 0      Teri maa ki chut me Shivsena ka lund gaya kya
# 1  Han muje pata hai teri maa ka ke gufa me jati thi
# 2  Tum kaha se aa gye bhai tumlog toh saree pehen...
# 3  Koi moti🙊kisi ki besti😁 baisn ka or channey ki...
# 4     Rahul kanwal aaj nanga hoke road per nachega 😂
#
#                                     Processed_Tweets  Bully_Label  \
# 0      Teri maa ki chut me Shivsena ka lund gaya kya            1
# 1  Han muje pata hai teri maa ka ke gufa me jati thi            1
# 2  Tum kaha se aa gye bhai tumlog toh saree pehen...            0
# 3  Koi motikisi ki besti baisn ka or channey ki d...            1
# 4       Rahul kanwal aaj nanga hoke road per nachega            1
#
#   Sentiment_label Emotion_label  \
# 0        Negative         Anger
# 1        Negative        Others
# 2         Neutral        Others
# 3        Negative       Disgust
# 4        Negative       Disgust
#
# ...

# %%
# splitting the text it further when '.' is seen.
data_into_list = text.replace('\n', ' ').split(".")
  
# printing the data
print(data_into_list)
#my_file.close()
# Out:
# ["a aadi aaj aap aapne aata aati aaya aaye ab abbe abbey abe abhi able about above accha according accordingly acha achcha across actually after afterwards again against agar ain aint ain't aisa aise aisi alag all allow allows almost alone along already also although always am among amongst an and andar another any anybody anyhow anyone anything anyway anyways anywhere ap apan apart apna apnaa apne apni appear are aren arent aren't around arre as aside ask asking at aur avum aya aye baad baar bad bahut bana banae banai banao banaya banaye banayi banda bande bandi bane bani bas bata batao bc be became because become becomes becoming been before beforehand behind being below beside besides best better between beyond bhai bheetar bhi bhitar bht bilkul bohot bol bola bole boli bolo bolta bolte bolti both brief bro btw but by came can cannot cant can't cause causes certain certainly chahiye chaiye chal chalega chhaiye clearly c'mon com come comes could couldn couldnt couldn't d de dede de
# ...

# %%
with open("stopwords.txt") as f:
    stopwords = f.read().splitlines() # Contains "and" and "or" on different lines

# %%
df['len'] = df['Tweets'].str.len()  # Store string length of each sample
#df = df.sort_values(['len'], ascending=True)
#df.head(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tweets'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data = /content/drive/MyDrive/Bully_Sent_Emo_IEEEIC_6084.csv
# Out:
#   File "<ipython-input-3-894f39406f4f>", line 1
#     data = /content/drive/MyDrive/Bully_Sent_Emo_IEEEIC_6084.csv
#            ^
# SyntaxError: invalid syntax
